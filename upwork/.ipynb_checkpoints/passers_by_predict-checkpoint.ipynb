# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

#File_name = input("please enter file name to open: ")
#future_days = int(future_days)
#print(dir(keras.losses))

#Data import.

#data = pd.read_csv(File_name,index_col=0, parse_dates=True)
data = pd.read_csv("long.csv", index_col=0, parse_dates=True, header=None)
data = data.astype('float')
print(data.head())
data.plot()
plt.show()
print(data[1])
print(len(data))
#data.drop('out', axis='columns', inplace=True)
#data.plot()
#data2.plot()
# Out:
#                         1
# 0
# 2021-03-31 05:50:00   3.0
# 2021-03-31 06:00:00  16.0
# 2021-03-31 06:10:00  23.0
# 2021-03-31 06:20:00  37.0
# 2021-03-31 06:30:00  59.0
# 0
# 2021-03-31 05:50:00     3.0
# 2021-03-31 06:00:00    16.0
# 2021-03-31 06:10:00    23.0
# 2021-03-31 06:20:00    37.0
# 2021-03-31 06:30:00    59.0
#                        ...
# 2021-03-27 21:50:00    48.0
# 2021-03-27 22:00:00    45.0
# 2021-03-27 22:10:00    50.0
# 2021-03-27 22:20:00    63.0
# 2021-03-27 22:30:00    36.0
# Name: 1, Length: 505, dtype: float64
# 505

# %%
#Scale data to a range of -1,1 and split to training and testing set.
scaler = StandardScaler()
scaler = scaler.fit(data)
dataset = scaler.transform(data)
train_data = int(len(dataset) * 0.9)
test_data = (int(len(dataset) - train_data ))
train, test = dataset[0:train_data], dataset[train_data:len(dataset)]

# %%
# Reshape data to lenght, timesteps and number of features.
n_future = 1 
n_past = 14 
def create_dataset(my_data, n_future, n_past):
    dataX = []
    dataY = []
    for i in range(n_past, len(my_data) - n_future +1):
        dataX.append(my_data[i - n_past:i, 0:my_data.shape[1]])
        dataY.append(my_data[i + n_future - 1:i + n_future, 0])
    return np.array(dataX), np.array(dataY)
trainX, trainY = create_dataset(train, n_future, n_past)
testX, testY = create_dataset(test, n_future, n_past)
print(trainX.shape)
print(trainY.shape)
# Out:
# (440, 14, 1)
# (440, 1)

# %%
#RNN model  starts.
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))
model.compile(optimizer='adam', loss='mse')
history = model.fit(trainX, trainY, epochs=30,validation_split=0.1, batch_size=32)
model.summary()
# Out:
# Epoch 1/30
# 44/44 [==============================] - 3s 18ms/step - loss: 0.5466 - val_loss: 0.3065
# Epoch 2/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.3080 - val_loss: 0.2549
# Epoch 3/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.2172 - val_loss: 0.2200
# Epoch 4/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1616 - val_loss: 0.0739
# Epoch 5/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.1384 - val_loss: 0.1614
# Epoch 6/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1402 - val_loss: 0.1582
# Epoch 7/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1312 - val_loss: 0.0941
# Epoch 8/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1206 - val_loss: 0.2618
# Epoch 9/30
# 44/44 [==============================] - 1s 11ms/step - loss: 0.1229 - val_loss: 0.2183
# Epoch 10/30
# 44/44 [==============================] - 1s 12ms/step - loss: 0.1108 - val_loss: 0.0786
# Epoch 11/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0992 - val_loss: 0.0726
# Epoch 12/30
# 44/44 [==============================] - 1s 12ms/step - loss: 0.1157 - val_loss: 0.0585
# Epoch 13/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1048 - val_loss: 0.1126
# Epoch 14/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1098 - val_loss: 0.1176
# Epoch 15/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1066 - val_loss: 0.0964
# Epoch 16/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1134 - val_loss: 0.0978
# Epoch 17/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0982 - val_loss: 0.1074
# Epoch 18/30
# 44/44 [==============================] - 1s 12ms/step - loss: 0.1018 - val_loss: 0.0710
# Epoch 19/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1002 - val_loss: 0.1106
# Epoch 20/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0824 - val_loss: 0.0805
# Epoch 21/30
# 44/44 [==============================] - 1s 12ms/step - loss: 0.1102 - val_loss: 0.0969
# Epoch 22/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0876 - val_loss: 0.1055
# Epoch 23/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0905 - val_loss: 0.0821
# Epoch 24/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0925 - val_loss: 0.1252
# Epoch 25/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0922 - val_loss: 0.1120
# Epoch 26/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0887 - val_loss: 0.0738
# Epoch 27/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0892 - val_loss: 0.1089
# Epoch 28/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0908 - val_loss: 0.1133
# Epoch 29/30
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0932 - val_loss: 0.1218
# Epoch 30/30
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0946 - val_loss: 0.0789
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 14, 64)            16896
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 29,345
# Trainable params: 29,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot model loss comparison.
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

#plot.scatter(xTrain, yTrain, color = 'red')
#plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
#plot.title('Salary vs Experience (Training set)')
#plot.xlabel('Years of Experience')plot.ylabel('Salary')
#plot.show()

# %%
# Create future date list.
future_prediction_real = 10
datelist_future = pd.date_range(datelist_train[-1], periods=future_prediction_real, freq="d").tolist()

# %%
# Predict future days.
prediction = model.predict(trainX[-future_prediction_real:])
print(prediction.shape)
prediction_copies = np.repeat(prediction, data.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6264f74670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (10, 1)

# %%
# Create date list table and future pediction table and combine side by side.
datelist_future_ = []
for i in datelist_future:
    datelist_future_.append(i.date())

# %%
data_forecust = pd.DataFrame({'FutureDates':np.array(datelist_future), 'Prediction':y_pred_future})
data_forecust['FutureDates']=pd.to_datetime(data_forecust['FutureDates'])

# %%
print(data_forecust)
# Out:
#           FutureDates  Prediction
# 0 2021-03-27 22:30:00  351.529419
# 1 2021-03-28 22:30:00  358.975739
# 2 2021-03-29 22:30:00  369.532837
# 3 2021-03-30 22:30:00  375.871216
# 4 2021-03-31 22:30:00  383.082275
# 5 2021-04-01 22:30:00  366.688232
# 6 2021-04-02 22:30:00  345.241211
# 7 2021-04-03 22:30:00  348.675659
# 8 2021-04-04 22:30:00  359.166473
# 9 2021-04-05 22:30:00  356.120697

# %%
original['Date']=pd.to_datetime(original.index)
#original = original.loc[original['Date'] >= '2020-5-1']

# %%
data.plot()
plt.show()

# %%
data_forecust.plot()
plt.show()
